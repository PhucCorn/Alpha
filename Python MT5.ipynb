# %% [markdown]
# # Trade with Python through MetaTrader5

# %%
# documentation: https://www.mql5.com/en/docs/integration/python_metatrader5

import MetaTrader5 as mt  # pip install MetaTrader5

import pandas as pd  # pip install pandas
import plotly.express as px  # pip install plotly
from datetime import datetime
import pandas as pd
import numpy as np
import sys
from F import send_to_telegram, portfolio_pnl_future

# %%
# start the platform with initialize()
mt.initialize()
# Out:
# True

# %%
# login to Trade Account with login()
# make sure that trade server is enabled in MT5 client terminal

# login = "SmallCityBoy"
# password = "7BjSjtpv"
# server = "ICMarketsSC-Demo"

# mt.login(login, password, server)

# %%
# login to Trade Account with login()
# make sure that trade server is enabled in MT5 client terminal
#@2YwUjSt
login = 42357521
password = "A%VkO!8Kb5rftq"
server = "Aglobe-Demo"

mt.login(login, password, server)
# Out:
# True

# %%
# get account info
account_info = mt.account_info()
print(account_info)

# getting specific account data
login_number = account_info.login
balance = account_info.balance
equity = account_info.equity

print()
print('login: ', login_number)
print('balance: ', balance)
print('equity: ', equity)
# Out:
# AccountInfo(login=42357521, trade_mode=0, leverage=1000, limit_orders=500, margin_so_mode=0, trade_allowed=True, trade_expert=True, margin_mode=2, currency_digits=2, fifo_close=False, balance=50000.0, credit=0.0, profit=0.0, equity=50000.0, margin=0.0, margin_free=50000.0, margin_level=0.0, margin_so_call=100.0, margin_so_so=30.0, margin_initial=0.0, margin_maintenance=0.0, assets=0.0, liabilities=0.0, commission_blocked=0.0, name='Phuc Ngo', server='Aglobe-Demo', currency='USD', company='Aglobe Investments Ltd.')
#
# login:  42357521
# balance:  50000.0
# equity:  50000.0

# %%
# get number of symbols with symbols_total()
num_symbols = mt.symbols_total()

num_symbols
# Out:
# 3078

# %%
# get all symbols and their specifications
symbols = mt.symbols_get()
symbols
# Out:
# (SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1700650925, digits=5, spread=7, spread_float=True, ticks_bookdepth=5, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=6, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=1.08876, bidhigh=1.09226, bidlow=1.08824, ask=1.08883, askhigh=1.09232, asklow=1.0883, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=1.0, trade_tick_value_profit=1.0, trade_tick_value_loss=1.0, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-12.48, swap_short=4.22, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=1.09076, session_close=1.091, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=100000.0, price_change=-0.2053, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='EUR', currency_profit='USD', currency_margin='EUR', bank='', description='Euro vs US Dollar', exchange='', formula='', isin='', name='EURUSD-T', page=' ', path='T-Forex\\Majors\\EURUSD-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1700650926, digits=5, spread=10, spread_float=True, ticks_bookdepth=5, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=20, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=1.25199, bidhigh=1.2549000000000001, bidlow=1.25064, ask=1.25209, askhigh=1.25503, asklow=1.25078, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=1.0, trade_tick_value_profit=1.0, trade_tick_value_loss=1.0, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-6.87, swap_short=-0.49, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=1.25289, session_close=1.25373, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=100000.0, price_change=-0.1388, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='GBP', currency_profit='USD', currency_margin='GBP', bank='', description='Great Britain Pound vs US Dollar', exchange='', formula='', isin='', name='GBPUSD-T', page=' ', path='T-Forex\\Majors\\GBPUSD-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1700650920, digits=5, spread=18, spread_float=True, ticks_bookdepth=5, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=32, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=1.37189, bidhigh=1.37275, bidlow=1.36898, ask=1.37207, askhigh=1.37294, asklow=1.36916, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=0.7288257887717101, trade_tick_value_profit=0.7288257887717101, trade_tick_value_loss=0.7289214149822508, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-3.17, swap_short=-4.16, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=1.36974, session_close=1.37015, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=100000.0, price_change=0.127, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='USD', currency_profit='CAD', currency_margin='USD', bank='', description='US Dollar vs Canadian Dollar', exchange='', formula='', isin='', name='USDCAD-T', page=' ', path='T-Forex\\Majors\\USDCAD-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1700650923, digits=5, spread=12, spread_float=True, ticks_bookdepth=5, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=24, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.88509, bidhigh=0.88618, bidlow=0.88279, ask=0.88521, askhigh=0.88633, asklow=0.88292, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=1.1296754442448687, trade_tick_value_profit=1.1296754442448687, trade_tick_value_loss=1.1298286050006214, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=6.33, swap_short=-20.41, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.88312, session_close=0.88359, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=100000.0, price_change=0.1698, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='USD', currency_profit='CHF', currency_margin='USD', bank='', description='US Dollar vs Swiss Franc', exchange='', formula='', isin='', name='USDCHF-T', page=' ', path='T-Forex\\Majors\\USDCHF-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1700650925, digits=3, spread=11, spread_float=True, ticks_bookdepth=5, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=16, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=149.275, bidhigh=149.348, bidlow=148.013, ask=149.286, askhigh=149.36, asklow=148.028, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.6698551773106655, trade_tick_value_profit=0.6698551773106655, trade_tick_value_loss=0.6699045386032491, trade_tick_size=0.001, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=15.82, swap_short=-30.28, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=148.33, session_close=148.395, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=100000.0, price_change=0.593, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='USD', currency_profit='JPY', currency_margin='USD', bank='', description='US Dollar vs Japanese Yen', exchange='', formula='', isin='', name='USDJPY-T', page=' ', path='T-Forex\\Majors\\USDJPY-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1700650924, digits=5, spread=33, spread_float=True, ticks_bookdepth=5, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=56, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.89742, bidhigh=0.89932, bidlow=0.8953, ask=0.89775, askhigh=0.89963, asklow=0.8956, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=0.7288257887717101, trade_tick_value_profit=0.7288257887717101, trade_tick_value_loss=0.7289214149822508, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-7.73, swap_short=0.1, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.89813, session_close=0.8981, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=100000.0, price_change=-0.0757, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='AUD', currency_profit='CAD', currency_margin='AUD', bank='', description='Australian Dollar vs Canadian Dollar', exchange='', formula='', isin='', name='AUDCAD-T', page='', path='T-Forex\\Minors\\AUDCAD-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1700650925, digits=5, spread=47, spread_float=True, ticks_bookdepth=5, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=92, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.57885, bidhigh=0.57985, bidlow=0.57712, ask=0.57932, askhigh=0.58062, asklow=0.57758, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=1.1296754442448687, trade_tick_value_profit=1.1296754442448687, trade_tick_value_loss=1.1298286050006214, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=2.4699999999999998, swap_short=-10.25, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.57886, session_close=0.579, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=100000.0, price_change=-0.0259, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='AUD', currency_profit='CHF', currency_margin='AUD', bank='', description='Australian Dollar vs Swiss Franc', exchange='', formula='', isin='', name='AUDCHF-T', page='', path='T-Forex\\Minors\\AUDCHF-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1700650926, digits=3, spread=27, spread_float=True, ticks_bookdepth=5, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=44, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=97.654, bidhigh=97.669, bidlow=97.07, ask=97.681, askhigh=97.694, asklow=97.095, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.6698551773106655, trade_tick_value_profit=0.6698551773106655, trade_tick_value_loss=0.6699045386032491, trade_tick_size=0.001, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=5.51, swap_short=-18.6, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=97.279, session_close=97.275, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=100000.0, price_change=0.3896, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='AUD', currency_profit='JPY', currency_margin='AUD', bank='', description='Australian Dollar vs Japanese Yen', exchange='', formula='', isin='', name='AUDJPY-T', page='', path='T-Forex\\Minors\\AUDJPY-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1700650925, digits=5, spread=35, spread_float=True, ticks_bookdepth=5, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=62, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=1.08637, bidhigh=1.08649, bidlow=1.08207, ask=1.08672, askhigh=1.08684, asklow=1.08313, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=0.602, trade_tick_value_profit=0.602, trade_tick_value_loss=0.6021900000000001, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-11.46, swap_short=0.92, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=1.08319, session_close=1.08268, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=100000.0, price_change=0.3408, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='AUD', currency_profit='NZD', currency_margin='AUD', bank='', description='Australian Dollar vs New Zealand Dollar', exchange='', formula='', isin='', name='AUDNZD-T', page='', path='T-Forex\\Minors\\AUDNZD-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1700650925, digits=5, spread=11, spread_float=True, ticks_bookdepth=5, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=20, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.65415, bidhigh=0.65693, bidlow=0.65272, ask=0.65426, askhigh=0.65704, asklow=0.65281, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=1.0, trade_tick_value_profit=1.0, trade_tick_value_loss=1.0, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-5.52, swap_short=0.62, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.65567, session_close=0.65552, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=100000.0, price_change=-0.209, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='AUD', currency_profit='USD', currency_margin='AUD', bank='', description='Australian Dollar vs US Dollar', exchange='', formula='', isin='', name='AUDUSD-T', page=' ', path='T-Forex\\Minors\\AUDUSD-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=5, spread=0, spread_float=True, ticks_bookdepth=5, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=100, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=1.1296754442448687, trade_tick_value_profit=1.1296754442448687, trade_tick_value_loss=1.1298286050006214, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=4.22, swap_short=-14.12, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=100000.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='CAD', currency_profit='CHF', currency_margin='CAD', bank='', description='Canadian Dollar vs Swiss Franc', exchange='', formula='', isin='', name='CADCHF-T', page='', path='T-Forex\\Minors\\CADCHF-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=5, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=62, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.6698551773106655, trade_tick_value_profit=0.6698551773106655, trade_tick_value_loss=0.6699045386032491, trade_tick_size=0.001, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=8.19, swap_short=-24.68, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=100000.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='CAD', currency_profit='JPY', currency_margin='CAD', bank='', description='Canadian Dollar vs Japanese Yen', exchange='', formula='', isin='', name='CADJPY-T', page=' ', path='T-Forex\\Minors\\CADJPY-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=5, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=126, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.6698551773106655, trade_tick_value_profit=0.6698551773106655, trade_tick_value_loss=0.6699045386032491, trade_tick_size=0.001, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=0.14, swap_short=-11.29, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=100000.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='CHF', currency_profit='JPY', currency_margin='CHF', bank='', description='Swiss Franc vs Japanese Yen', exchange='', formula='', isin='', name='CHFJPY-T', page=' ', path='T-Forex\\Minors\\CHFJPY-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=5, spread=0, spread_float=True, ticks_bookdepth=5, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=54, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=0.6541500000000001, trade_tick_value_profit=0.6541500000000001, trade_tick_value_loss=0.65426, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-14.93, swap_short=0.68, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=100000.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='EUR', currency_profit='AUD', currency_margin='EUR', bank='', description='Euro vs Australian Dollar', exchange='', formula='', isin='', name='EURAUD-T', page=' ', path='T-Forex\\Minors\\EURAUD-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=5, spread=0, spread_float=True, ticks_bookdepth=5, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=76, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=0.7288257887717101, trade_tick_value_profit=0.7288257887717101, trade_tick_value_loss=0.7289214149822508, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-19.49, swap_short=3.73, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=100000.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='EUR', currency_profit='CAD', currency_margin='EUR', bank='', description='Euro vs Canadian Dollar', exchange='', formula='', isin='', name='EURCAD-T', page=' ', path='T-Forex\\Minors\\EURCAD-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=5, spread=0, spread_float=True, ticks_bookdepth=5, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=34, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=1.1296754442448687, trade_tick_value_profit=1.1296754442448687, trade_tick_value_loss=1.1298286050006214, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=1.74, swap_short=-11.05, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=100000.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='EUR', currency_profit='CHF', currency_margin='EUR', bank='', description='Euro vs Swiss Franc', exchange='', formula='', isin='', name='EURCHF-T', page=' ', path='T-Forex\\Minors\\EURCHF-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=5, spread=0, spread_float=True, ticks_bookdepth=5, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=20, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=1.25199, trade_tick_value_profit=1.25199, trade_tick_value_loss=1.2520900000000001, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-8.13, swap_short=1.26, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=100000.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='EUR', currency_profit='GBP', currency_margin='EUR', bank='', description='Euro vs Great Britain Pound', exchange='', formula='', isin='', name='EURGBP-T', page=' ', path='T-Forex\\Minors\\EURGBP-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=5, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=30, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.6698551773106655, trade_tick_value_profit=0.6698551773106655, trade_tick_value_loss=0.6699045386032491, trade_tick_size=0.001, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=5.45, swap_short=-22.54, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=100000.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='EUR', currency_profit='JPY', currency_margin='EUR', bank='', description='Euro vs Japanese Yen', exchange='', formula='', isin='', name='EURJPY-T', page=' ', path='T-Forex\\Minors\\EURJPY-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=5, spread=0, spread_float=True, ticks_bookdepth=5, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=100, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=0.602, trade_tick_value_profit=0.602, trade_tick_value_loss=0.6021900000000001, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-26.61, swap_short=5.71, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=100000.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='EUR', currency_profit='NZD', currency_margin='EUR', bank='', description='Euro vs New Zealand Dollar', exchange='', formula='', isin='', name='EURNZD-T', page=' ', path='T-Forex\\Minors\\EURNZD-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=5, spread=0, spread_float=True, ticks_bookdepth=5, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=106, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=0.6541500000000001, trade_tick_value_profit=0.6541500000000001, trade_tick_value_loss=0.65426, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-2.98, swap_short=-10.39, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=100000.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='GBP', currency_profit='AUD', currency_margin='GBP', bank='', description='Great Britain Pound vs Australian Dollar', exchange='', formula='', isin='', name='GBPAUD-T', page=' ', path='T-Forex\\Minors\\GBPAUD-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=5, spread=0, spread_float=True, ticks_bookdepth=5, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=114, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=0.7288257887717101, trade_tick_value_profit=0.7288257887717101, trade_tick_value_loss=0.7289214149822508, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-10.13, swap_short=-2.01, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=100000.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='GBP', currency_profit='CAD', currency_margin='GBP', bank='', description='Great Britain Pound vs Canadian Dollar', exchange='', formula='', isin='', name='GBPCAD-T', page=' ', path='T-Forex\\Minors\\GBPCAD-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=5, spread=0, spread_float=True, ticks_bookdepth=5, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=112, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=1.1296754442448687, trade_tick_value_profit=1.1296754442448687, trade_tick_value_loss=1.1298286050006214, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=5.5, swap_short=-20.08, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=100000.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='GBP', currency_profit='CHF', currency_margin='GBP', bank='', description='Great Britain Pound vs Swiss Franc', exchange='', formula='', isin='', name='GBPCHF-T', page=' ', path='T-Forex\\Minors\\GBPCHF-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=3, spread=0, spread_float=True, ticks_bookdepth=5, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=48, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.001, trade_tick_value=0.6698551773106655, trade_tick_value_profit=0.6698551773106655, trade_tick_value_loss=0.6699045386032491, trade_tick_size=0.001, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=14.88, swap_short=-30.42, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=100000.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='GBP', currency_profit='JPY', currency_margin='GBP', bank='', description='Great Britain Pound vs Japanese Yen', exchange='', formula='', isin='', name='GBPJPY-T', page=' ', path='T-Forex\\Minors\\GBPJPY-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=5, spread=0, spread_float=True, ticks_bookdepth=5, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=154, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=0.602, trade_tick_value_profit=0.602, trade_tick_value_loss=0.6021900000000001, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-16.35, swap_short=0.22, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=100000.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='GBP', currency_profit='NZD', currency_margin='GBP', bank='', description='Great Britain Pound vs New Zealand Dollar', exchange='', formula='', isin='', name='GBPNZD-T', page=' ', path='T-Forex\\Minors\\GBPNZD-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=5, spread=0, spread_float=True, ticks_bookdepth=5, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=72, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=0.7288257887717101, trade_tick_value_profit=0.7288257887717101, trade_tick_value_loss=0.7289214149822508, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume_step=0.01, volume_limit=0.0, swap_long=-1.83, swap_short=-4.85, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=100000.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='NZD', currency_profit='CAD', currency_margin='NZD', bank='', description='New Zealand Dollar vs Canadian Dollar', exchange='', formula='', isin='', name='NZDCAD-T', page=' ', path='T-Forex\\Minors\\NZDCAD-T'),
# ...
#  SymbolInfo(custom=False, chart_mode=0, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=2, spread=0, spread_float=True, ticks_bookdepth=3, trade_calc_mode=4, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=58, trade_freeze_level=0, trade_exemode=2, swap_mode=5, swap_rollover3days=5, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.01, trade_tick_value=0.01, trade_tick_value_profit=0.01, trade_tick_value_loss=0.01, trade_tick_size=0.01, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=500.0, volume_step=1.0, volume_limit=0.0, swap_long=-7.49, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=1.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='USD', currency_profit='USD', currency_margin='USD', bank='', description='Sherwin-Williams Co-The CFD(15 min delay)', exchange='', formula='', isin='US8243481061', name='#SHW-T', page='', path='T-Stock CFDs\\US (NASDAQ)\\#SHW-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=2, spread=0, spread_float=True, ticks_bookdepth=1, trade_calc_mode=4, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=11, trade_freeze_level=0, trade_exemode=2, swap_mode=5, swap_rollover3days=5, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.01, trade_tick_value=0.01, trade_tick_value_profit=0.01, trade_tick_value_loss=0.01, trade_tick_size=0.01, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=500.0, volume_step=1.0, volume_limit=0.0, swap_long=-7.49, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=1.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='USD', currency_profit='USD', currency_margin='USD', bank='', description='Selective Insurance Group Inc CFD(15min delay)', exchange='', formula='', isin='US8163001071', name='#SIGI-T', page='', path='T-Stock CFDs\\US (NASDAQ)\\#SIGI-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=2, spread=0, spread_float=True, ticks_bookdepth=1, trade_calc_mode=4, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=1, trade_freeze_level=0, trade_exemode=2, swap_mode=5, swap_rollover3days=5, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.01, trade_tick_value=0.01, trade_tick_value_profit=0.01, trade_tick_value_loss=0.01, trade_tick_size=0.01, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=500.0, volume_step=1.0, volume_limit=0.0, swap_long=-7.49, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=1.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='USD', currency_profit='USD', currency_margin='USD', bank='', description='Sirius XM Holdings Inc. CFD(15min delay)', exchange='', formula='', isin='US82968B1035', name='#SIRI-T', page='', path='T-Stock CFDs\\US (NASDAQ)\\#SIRI-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=2, spread=0, spread_float=True, ticks_bookdepth=1, trade_calc_mode=4, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=11, trade_freeze_level=0, trade_exemode=2, swap_mode=5, swap_rollover3days=5, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.01, trade_tick_value=0.01, trade_tick_value_profit=0.01, trade_tick_value_loss=0.01, trade_tick_size=0.01, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=500.0, volume_step=1.0, volume_limit=0.0, swap_long=-7.49, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=1.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='USD', currency_profit='USD', currency_margin='USD', bank='', description='SkyWest Inc CFD(15min delay)', exchange='', formula='', isin='US8308791024', name='#SKYW-T', page='', path='T-Stock CFDs\\US (NASDAQ)\\#SKYW-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=2, spread=0, spread_float=True, ticks_bookdepth=1, trade_calc_mode=4, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=11, trade_freeze_level=0, trade_exemode=2, swap_mode=5, swap_rollover3days=5, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.01, trade_tick_value=0.01, trade_tick_value_profit=0.01, trade_tick_value_loss=0.01, trade_tick_size=0.01, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=500.0, volume_step=1.0, volume_limit=0.0, swap_long=-7.49, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=1.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='USD', currency_profit='USD', currency_margin='USD', bank='', description='Silicon Laboratories Inc CFD(15min delay)', exchange='', formula='', isin='US8269191024', name='#SLAB-T', page='', path='T-Stock CFDs\\US (NASDAQ)\\#SLAB-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=2, spread=0, spread_float=True, ticks_bookdepth=1, trade_calc_mode=4, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=5, trade_freeze_level=0, trade_exemode=2, swap_mode=5, swap_rollover3days=5, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.01, trade_tick_value=0.01, trade_tick_value_profit=0.01, trade_tick_value_loss=0.01, trade_tick_size=0.01, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=500.0, volume_step=1.0, volume_limit=0.0, swap_long=-7.49, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=1.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='USD', currency_profit='USD', currency_margin='USD', bank='', description='SL Green Realty Corp CFD(15min delay)', exchange='', formula='', isin='US78440X8048', name='#SLG-T', page='', path='T-Stock CFDs\\US (NASDAQ)\\#SLG-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=2, spread=0, spread_float=True, ticks_bookdepth=1, trade_calc_mode=4, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=3, trade_freeze_level=0, trade_exemode=2, swap_mode=5, swap_rollover3days=5, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.01, trade_tick_value=0.01, trade_tick_value_profit=0.01, trade_tick_value_loss=0.01, trade_tick_size=0.01, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=500.0, volume_step=1.0, volume_limit=0.0, swap_long=-7.49, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=1.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='USD', currency_profit='USD', currency_margin='USD', bank='', description='Silgan Holdings Inc CFD(15min delay)', exchange='', formula='', isin='US8270481091', name='#SLGN-T', page='', path='T-Stock CFDs\\US (NASDAQ)\\#SLGN-T'),
#  SymbolInfo(custom=False, chart_mode=0, select=False, visible=False, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=0, digits=2, spread=0, spread_float=True, ticks_bookdepth=1, trade_calc_mode=4, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=1, trade_freeze_level=0, trade_exemode=2, swap_mode=5, swap_rollover3days=5, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=3, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.0, bidhigh=0.0, bidlow=0.0, ask=0.0, askhigh=0.0, asklow=0.0, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=0.01, trade_tick_value=0.01, trade_tick_value_profit=0.01, trade_tick_value_loss=0.01, trade_tick_size=0.01, trade_contract_size=1.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=1.0, volume_max=500.0, volume_step=1.0, volume_limit=0.0, swap_long=-7.49, swap_short=0.0, margin_initial=0.0, margin_maintenance=0.0, session_volume=0.0, session_turnover=0.0, session_interest=0.0, session_buy_orders_volume=0.0, session_sell_orders_volume=0.0, session_open=0.0, session_close=0.0, session_aw=0.0, session_price_settlement=0.0, session_price_limit_min=0.0, session_price_limit_max=0.0, margin_hedged=1.0, price_change=0.0, price_volatility=0.0, price_theoretical=0.0, price_greeks_delta=0.0, price_greeks_theta=0.0, price_greeks_gamma=0.0, price_greeks_vega=0.0, price_greeks_rho=0.0, price_greeks_omega=0.0, price_sensitivity=0.0, basis='', category='', currency_base='USD', currency_profit='USD', currency_margin='USD', bank='', description='SLM Corp CFD(15min delay)', exchange='', formula='', isin='US78442P1066', name='#SLM-T', page='', path='T-Stock CFDs\\US (NASDAQ)\\#SLM-T'),
#  ...)

# %%
# get symbol specifications
symbol_info = mt.symbol_info("GBPUSD-T")._asdict()
symbol_info
# Out:
# {'custom': False,
#  'chart_mode': 0,
#  'select': True,
#  'visible': True,
#  'session_deals': 0,
#  'session_buy_orders': 0,
#  'session_sell_orders': 0,
#  'volume': 0,
#  'volumehigh': 0,
#  'volumelow': 0,
#  'time': 1700650940,
#  'digits': 5,
#  'spread': 11,
#  'spread_float': True,
#  'ticks_bookdepth': 5,
#  'trade_calc_mode': 0,
#  'trade_mode': 4,
#  'start_time': 0,
#  'expiration_time': 0,
#  'trade_stops_level': 20,
#  'trade_freeze_level': 0,
#  'trade_exemode': 2,
#  'swap_mode': 1,
#  'swap_rollover3days': 3,
#  'margin_hedged_use_leg': False,
#  'expiration_mode': 15,
#  'filling_mode': 3,
#  'order_mode': 127,
#  'order_gtc_mode': 0,
#  'option_mode': 0,
#  'option_right': 0,
#  'bid': 1.25207,
#  'bidhigh': 1.2549000000000001,
#  'bidlow': 1.25064,
#  'ask': 1.25218,
#  'askhigh': 1.25503,
#  'asklow': 1.25078,
#  'last': 0.0,
#  'lasthigh': 0.0,
#  'lastlow': 0.0,
#  'volume_real': 0.0,
#  'volumehigh_real': 0.0,
#  'volumelow_real': 0.0,
#  'option_strike': 0.0,
#  'point': 1e-05,
#  'trade_tick_value': 1.0,
#  'trade_tick_value_profit': 1.0,
#  'trade_tick_value_loss': 1.0,
#  'trade_tick_size': 1e-05,
#  'trade_contract_size': 100000.0,
#  'trade_accrued_interest': 0.0,
#  'trade_face_value': 0.0,
#  'trade_liquidity_rate': 0.0,
#  'volume_min': 0.01,
#  'volume_max': 100.0,
#  'volume_step': 0.01,
#  'volume_limit': 0.0,
#  'swap_long': -6.87,
#  'swap_short': -0.49,
#  'margin_initial': 0.0,
#  'margin_maintenance': 0.0,
#  'session_volume': 0.0,
#  'session_turnover': 0.0,
#  'session_interest': 0.0,
#  'session_buy_orders_volume': 0.0,
#  'session_sell_orders_volume': 0.0,
#  'session_open': 1.25289,
#  'session_close': 1.25373,
#  'session_aw': 0.0,
#  'session_price_settlement': 0.0,
#  'session_price_limit_min': 0.0,
#  'session_price_limit_max': 0.0,
#  'margin_hedged': 100000.0,
#  'price_change': -0.1324,
#  'price_volatility': 0.0,
#  'price_theoretical': 0.0,
#  'price_greeks_delta': 0.0,
#  'price_greeks_theta': 0.0,
#  'price_greeks_gamma': 0.0,
#  'price_greeks_vega': 0.0,
#  'price_greeks_rho': 0.0,
#  'price_greeks_omega': 0.0,
#  'price_sensitivity': 0.0,
#  'basis': '',
#  'category': '',
#  'currency_base': 'GBP',
#  'currency_profit': 'USD',
#  'currency_margin': 'GBP',
#  'bank': '',
#  'description': 'Great Britain Pound vs US Dollar',
#  'exchange': '',
#  'formula': '',
#  'isin': '',
#  'name': 'GBPUSD-T',
#  'page': ' ',
#  'path': 'T-Forex\\Majors\\GBPUSD-T'}

# %%
def get_data_FX(symbol, timeframe, rows):
    ohlc_data = pd.DataFrame(mt.copy_rates_from_pos(symbol, timeframe, 0, rows))
    print(ohlc_data)
get_data_FX('GBPUSD-T', timeframe=mt.TIMEFRAME_M15, rows=99999)
# Out:
#              time     open     high      low    close  tick_volume  spread  \
# 0      1573806600  1.28787  1.28794  1.28773  1.28779          342       7
# 1      1573807500  1.28779  1.28841  1.28779  1.28827          519       7
# 2      1573808400  1.28835  1.28835  1.28763  1.28773          916       7
# 3      1573809300  1.28772  1.28825  1.28767  1.28770          336       7
# 4      1573810200  1.28770  1.28774  1.28716  1.28753          550       7
# ...           ...      ...      ...      ...      ...          ...     ...
# 99994  1700647200  1.25262  1.25367  1.25261  1.25357         1214       8
# 99995  1700648100  1.25358  1.25358  1.25195  1.25204         1343       8
# 99996  1700649000  1.25205  1.25211  1.25076  1.25079         1124       8
# 99997  1700649900  1.25078  1.25139  1.25064  1.25126         1473       8
# 99998  1700650800  1.25125  1.25242  1.25125  1.25230          438       8
#
#        real_volume
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 99994            0
# 99995            0
# 99996            0
# 99997            0
# 99998            0
#
# [99999 rows x 8 columns]

# %%
def get_data_FX(symbol, timeframe, rows):
    ohlc_data = pd.DataFrame(mt.copy_rates_from_pos(symbol, timeframe, 0, rows))
    print(ohlc_data)
    ohlc_data['time'] = ohlc_data.apply(lambda x: datetime.fromtimestamp(x["time"]), axis=1)
    ohlc_data = ohlc_data.rename(columns={'time': 'Date', 'open': 'Open', 'high': 'High', 'low': 'Low', 'close': 'Close', 'real_volume': 'Volume'})
    ohlc_data.set_index("Date", inplace=True)
    return ohlc_data

get_data_FX('GBPUSD-T', timeframe=mt.TIMEFRAME_M15, rows=99999)
# Out:
#              time     open     high      low    close  tick_volume  spread  \
# 0      1573806600  1.28787  1.28794  1.28773  1.28779          342       7
# 1      1573807500  1.28779  1.28841  1.28779  1.28827          519       7
# 2      1573808400  1.28835  1.28835  1.28763  1.28773          916       7
# 3      1573809300  1.28772  1.28825  1.28767  1.28770          336       7
# 4      1573810200  1.28770  1.28774  1.28716  1.28753          550       7
# ...           ...      ...      ...      ...      ...          ...     ...
# 99994  1700647200  1.25262  1.25367  1.25261  1.25357         1214       8
# 99995  1700648100  1.25358  1.25358  1.25195  1.25204         1343       8
# 99996  1700649000  1.25205  1.25211  1.25076  1.25079         1124       8
# 99997  1700649900  1.25078  1.25139  1.25064  1.25126         1473       8
# 99998  1700650800  1.25125  1.25250  1.25125  1.25246          491       8
#
#        real_volume
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 99994            0
# 99995            0
# 99996            0
# 99997            0
# 99998            0
#
# [99999 rows x 8 columns]
#                         Open     High      Low    Close  tick_volume  spread  \
# Date
# 2019-11-15 15:30:00  1.28787  1.28794  1.28773  1.28779          342       7
# 2019-11-15 15:45:00  1.28779  1.28841  1.28779  1.28827          519       7
# 2019-11-15 16:00:00  1.28835  1.28835  1.28763  1.28773          916       7
# 2019-11-15 16:15:00  1.28772  1.28825  1.28767  1.28770          336       7
# 2019-11-15 16:30:00  1.28770  1.28774  1.28716  1.28753          550       7
# ...                      ...      ...      ...      ...          ...     ...
# 2023-11-22 17:00:00  1.25262  1.25367  1.25261  1.25357         1214       8
# 2023-11-22 17:15:00  1.25358  1.25358  1.25195  1.25204         1343       8
# 2023-11-22 17:30:00  1.25205  1.25211  1.25076  1.25079         1124       8
# 2023-11-22 17:45:00  1.25078  1.25139  1.25064  1.25126         1473       8
# 2023-11-22 18:00:00  1.25125  1.25250  1.25125  1.25246          491       8
#
#                      Volume
# Date
# 2019-11-15 15:30:00       0
# 2019-11-15 15:45:00       0
# 2019-11-15 16:00:00       0
# 2019-11-15 16:15:00       0
# 2019-11-15 16:30:00       0
# ...                     ...
# 2023-11-22 17:00:00       0
# 2023-11-22 17:15:00       0
# 2023-11-22 17:30:00       0
# 2023-11-22 17:45:00       0
# 2023-11-22 18:00:00       0
#
# [99999 rows x 7 columns]

# %%
data = get_data_FX('EURUSD-T', timeframe=mt.TIMEFRAME_H1, rows=90000)
data.to_csv('EURUSD-T.csv')
# Out:
#              time     open     high      low    close  tick_volume  spread  \
# 0      1242237600  1.36044  1.36314  1.35986  1.36110         5445      20
# 1      1242241200  1.36109  1.36557  1.36008  1.36080         4810      20
# 2      1242244800  1.36081  1.36121  1.35658  1.35950         5090      20
# 3      1242248400  1.35949  1.36114  1.35805  1.36098         4003      20
# 4      1242252000  1.36099  1.36120  1.35715  1.35808         4149      20
# ...           ...      ...      ...      ...      ...          ...     ...
# 89995  1700636400  1.09133  1.09144  1.09048  1.09071         1514       6
# 89996  1700640000  1.09070  1.09073  1.08954  1.09001         1858       6
# 89997  1700643600  1.09001  1.09164  1.08996  1.09143         2919       6
# 89998  1700647200  1.09143  1.09196  1.08824  1.08851         4038       6
# 89999  1700650800  1.08851  1.08928  1.08846  1.08923          424       6
#
#        real_volume
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 89995            0
# 89996            0
# 89997            0
# 89998            0
# 89999            0
#
# [90000 rows x 8 columns]

# %%
# from datetime import datetime
# import MetaTrader5 as mt

# # display data on the MetaTrader 5 package
# print("MetaTrader5 package author: ",mt.__author__)
# print("MetaTrader5 package version: ",mt.__version__)

# # import the 'pandas' module for displaying data obtained in the tabular form
# import pandas as pd
# pd.set_option('display.max_columns', 5000) # number of columns to be displayed
# pd.set_option('display.width', 15000) # max table width to display

# # import pytz module for working with time zone
# import pytz
# # establish connection to MetaTrader 5 terminal
# if not mt.initialize():
#     print("initialize() failed, error code =",mt.last_error())
#     quit()
# # set time zone to UTC
# timezone = pytz.timezone("Etc/UTC")

# # create 'datetime' objects in UTC time zone to avoid the implementation of a local time zone offset
# utc_from = datetime(2015, 1, 1, tzinfo=timezone)
# utc_to = datetime(2020, 5, 5, tzinfo=timezone)

# # get bars from USDZAR H1 within the interval of 2020.01.01 00:00 - 2020.05.05 in UTC time zone

# UCrateH = mt.copy_rates_range("JPYUSD", mt.TIMEFRAME_H1, utc_from, utc_to)

# # shut down connection to the MetaTrader 5 terminal
# mt.shutdown()

# # create DataFrame out of the obtained data
# UZH= pd.DataFrame(UCrateH)
# print(UZH.head(3))

# %%
# from datetime import datetime
# import MetaTrader5 as mt
# # display data on the MetaTrader 5 package
# print("MetaTrader5 package author: ",mt.__author__)
# print("MetaTrader5 package version: ",mt.__version__)
 
# # import the 'pandas' module for displaying data obtained in the tabular form
# import pandas as pd
# pd.set_option('display.max_columns', 500) # number of columns to be displayed
# pd.set_option('display.width', 1500)      # max table width to display
 
# # establish connection to MetaTrader 5 terminal
# if not mt.initialize():
#     print("initialize() failed, error code =",mt.last_error())
#     quit()

# list_ticket = ['AUDUSD', 'EURUSD', 'GBPUSD', 'NZDUSD', 'USDCHF', 'USDJPY', 'USDCAD', 'XAUUSD']

# for ticket in list_ticket:
#     try:
#         # ticket = "CADUSD"
#         # get 10 GBPUSD D1 bars from the current day
#         rates = mt.copy_rates_from_pos(ticket, mt.TIMEFRAME_H1, 0, 99999)
        
#         # shut down connection to the MetaTrader 5 terminal

#         # display each element of obtained data in a new line
#         # print("Display obtained data 'as is'")
#         # for rate in rates:
#         #     print(rate)
        
#         # create DataFrame out of the obtained data
#         rates_frame = pd.DataFrame(rates)
#         # convert time in seconds into the datetime format
#         rates_frame['time']=pd.to_datetime(rates_frame['time'], unit='s')
#         rates_frame.set_index("time", inplace=True)
        
#         # display data
#         print("\nDisplay dataframe with data")
#         # print(rates_frame)
#         rates_frame
#         rates_frame.to_csv(f"Data/FX/{ticket}_1H.csv")
#     except:
#         print(f"Error: {ticket}")

# mt.shutdown()

# %%
# ticket = list_ticket[2]
# df = pd.read_csv(f"Data/FX/{ticket}_15M.csv", index_col=0, parse_dates=True)
# print(ticket)
# df['close'].plot(figsize=(15, 6))

# %%
# df['2017-01-01':].to_csv(f"Data/FX/{ticket}_30M.csv")

# %%
# get current symbol price
symbol_price = mt.symbol_info_tick("EURUSD-T")._asdict()
symbol_price
# Out:
# {'time': 1700651238,
#  'bid': 1.0894,
#  'ask': 1.08947,
#  'last': 0.0,
#  'volume': 0,
#  'time_msc': 1700651238232,
#  'flags': 4,
#  'volume_real': 0.0}

# %%
# total number of orders
num_orders = mt.orders_total()
num_orders
# Out:
# 0

# %%
# list of orders
orders = mt.orders_get()
orders
# Out:
# ()

# %%
# total number of positions
num_positions = mt.positions_total()
num_positions
# Out:
# 0

# %%
# list of positions
positions = mt.positions_get()
positions
# Out:
# ()

# %%
# number of history orders
num_order_history = mt.history_orders_total(datetime(2021, 1, 1), datetime(2023, 11, 12))
num_order_history
# Out:
# 0

# %%
# list of history orders
order_history = mt.history_orders_get(datetime(2021, 1, 1), datetime(2023, 11, 12))
order_history
# Out:
# ()

# %%
# number of history deals
num_deal_history = mt.history_deals_total(datetime(2021, 1, 1), datetime(2023, 11, 12))
num_deal_history
# Out:
# 0

# %%
# number of history deals
deal_history = mt.history_deals_get(datetime(2021, 1, 1), datetime(2023, 11, 12))
deal_history
# Out:
# ()

# %%
# send order to the market
# documentation: https://www.mql5.com/en/docs/integration/python_metatrader5/mt5ordersend_py

request = {
    "action": mt.TRADE_ACTION_DEAL,
    "symbol": "EURUSD-T",
    "volume": 2.0, # FLOAT
    "type": mt.ORDER_TYPE_BUY,
    "price": mt.symbol_info_tick("EURUSD-T").ask,
    "sl": 0.0, # FLOAT
    "tp": 0.0, # FLOAT
    "deviation": 20, # INTERGER
    "magic": 234000, # INTERGER
    "comment": "python script open",
    "type_time": mt.ORDER_TIME_GTC,
    "type_filling": mt.ORDER_FILLING_IOC,
}

order = mt.order_send(request)
print(order.order)
# Out:
# 0

# %%
print(mt.positions_get())
# Out:
# ()

# %%
# close position

request = {
    "action": mt.TRADE_ACTION_DEAL,
    "symbol": "EURUSD-T",
    "volume": 2.0, # FLOAT
    "type": mt.ORDER_TYPE_SELL,
    "position": 415650175, # select the position you want to close
    "price": mt.symbol_info_tick("EURUSD-T").ask,
    "sl": 0.0, # FLOAT
    "tp": 0.0, # FLOAT
    "deviation": 20, # INTERGER
    "magic": 234000, # INTERGER
    "comment": "python script open",
    "type_time": mt.ORDER_TIME_GTC,
    "type_filling": mt.ORDER_FILLING_IOC,
}

order = mt.order_send(request)
print(order)
# Out:
# OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='EURUSD-T', volume=2.0, price=1.08958, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=1, type_time=0, expiration=0, comment='python script open', position=415650175, position_by=0))

# %%
import sys
sys.path.append('D:/Quant_trade')
import requests
import numpy as np
import pandas as pd
from ta import volume, momentum, trend, volatility, add_all_ta_features, others
import datetime
from tqdm import tqdm
import sqlalchemy
from datetime import time
from time import sleep
from F import DumpCSV_and_MesToTele_FX, PNL_per_day, get_data_realtime, get_data_FX
from itertools import combinations
import MetaTrader5 as mt

mt.initialize()

login = 9865828
password = "cwB#VF#6"
server = "FBS-Demo"

mt.login(login, password, server)

for i in range(10):
    try:
        test = get_data_FX('BTCUSD', timeframe=mt.TIMEFRAME_H1, rows=1000)
        break
    except Exception as e:
        print(e)

test['Pos'] = 0
lst_time = [time(i, 0) for i in range(24)]
test.reset_index(inplace=True)

# BTC_PHU_CCI1

PS = 'BTC_PHU_CCI1'
name = f'PS_PHU_{PS}'
path_csv_intraday = f'../Data/Total_gain_{PS}.csv'
path_csv_daily = f'../nas/{name}.csv'
token = '5882794375:AAHxM9d3jR9Mohqo8fM2rH4TbQA4uFzoE6E'
id = '-4047142092'
position = 0.01

############################################################################################
params = {'a': 200, 'b': 81, 'c': 16, 'd': 143, 'e': 124, 'f': 193, 'g': 15, 'h': 18}
a = params['a']
b = params['b']
c = params['c']
d = params['d']
e = params['e']
f = params['f']*0.1
g = params['g']
h = params['h']

drop_time = lst_time[g:h]

window1 = a
window2 = b
window_std = c
CCI_long = d
CCI_short = e
std_threshold1 = f

test['signal_long'] = np.nan
test['Close_MA'] = test['Close'].rolling(5).mean()
test['std'] = test['Close'].rolling(window_std).std()
test[f'CCI{window1}'] = trend.CCIIndicator(test['High'], test['Low'], test['Close_MA'], window1).cci()
test[f'CCI{window2}'] = trend.CCIIndicator(test['High'], test['Low'], test['Close_MA'], window2).cci()

test.loc[(test[f'CCI{window1}']>CCI_long), 'signal_long'] = 1
test.loc[(test[f'CCI{window2}']<=CCI_short)&(test['std'] > std_threshold1), 'signal_long'] = 0
test.loc[~test['Date'].dt.time.isin(drop_time), 'signal_long'] = 0
test['signal_long'] = test['signal_long'].ffill()
test['Pos'] += test['signal_long']

############################################################################################
params = {'a': 88, 'b': 186, 'c': 3, 'd': 193, 'e': 41, 'f': 142, 'g': 6, 'h': 12}
a = params['a']
b = params['b']
c = params['c']
d = params['d']
e = params['e']
f = params['f']*0.1
g = params['g']
h = params['h']

drop_time = lst_time[g:h]

window1 = a
window2 = b
window_std = c
CCI_long = d
CCI_short = e
std_threshold1 = f

test['signal_long'] = np.nan
test['Close_MA'] = test['Close'].rolling(5).mean()
test['std'] = test['Close'].rolling(window_std).std()
test[f'CCI{window1}'] = trend.CCIIndicator(test['High'], test['Low'], test['Close_MA'], window1).cci()
test[f'CCI{window2}'] = trend.CCIIndicator(test['High'], test['Low'], test['Close_MA'], window2).cci()

test.loc[(test[f'CCI{window1}']>CCI_long), 'signal_long'] = 1
test.loc[(test[f'CCI{window2}']<=CCI_short)&(test['std'] > std_threshold1), 'signal_long'] = 0
test.loc[test['Date'].dt.time.isin(drop_time), 'signal_long'] = 0
test['signal_long'] = test['signal_long'].ffill()
test['Pos'] += test['signal_long']

############################################################################################
params = {'a': 29, 'b': 98, 'c': 100, 'd': -167, 'e': -155, 'f': 159, 'g': 1, 'h': 2}
a = params['a']
b = params['b']
c = params['c']
d = params['d']
e = params['e']
f = params['f']*0.1
g = params['g']
h = params['h']

drop_time = lst_time[g:h]

window1 = a
window2 = b
window_std = c
CCI_long = d
CCI_short = e
std_threshold1 = f

test['signal_long'] = np.nan
test['Close_MA'] = test['Close'].rolling(5).mean()
test['std'] = test['Close'].rolling(window_std).std()
test[f'CCI{window1}'] = trend.CCIIndicator(test['High'], test['Low'], test['Close_MA'], window1).cci()
test[f'CCI{window2}'] = trend.CCIIndicator(test['High'], test['Low'], test['Close_MA'], window2).cci()

test.loc[(test[f'CCI{window1}']<CCI_long), 'signal_long'] = -1
test.loc[(test[f'CCI{window2}']>=CCI_short)&(test['std'] > std_threshold1), 'signal_long'] = 0
test.loc[test['Date'].dt.time.isin(drop_time), 'signal_long'] = 0
test['signal_long'] = test['signal_long'].ffill()
test['Pos'] += test['signal_long']

test.loc[test['Pos'] > 0, 'Pos'] = 1
test.loc[test['Pos'] < 0, 'Pos'] = -1

test
# test_update = get_data_FX('BTCUSD', timeframe=mt.TIMEFRAME_H1, rows=1000)
# df_csv, inputPos, CP = DumpCSV_and_MesToTele_FX(name, 'BTCUSD', path_csv_intraday, test['Pos'], test_update['Close'], token, id, position, fee=20)
# df_daily = PNL_per_day(path_csv_daily, df_csv['profit_today'])
# Out:
#                    Date      Open      High       Low     Close  tick_volume
# 0   2023-10-04 03:00:00  27370.44  27476.88  27369.79  27422.84         2982  \
# 1   2023-10-04 04:00:00  27422.84  27434.34  27283.11  27284.94         2951
# 2   2023-10-04 05:00:00  27284.94  27416.54  27231.18  27262.54         4651
# 3   2023-10-04 06:00:00  27262.54  27385.84  27139.39  27383.34         4599
# 4   2023-10-04 07:00:00  27383.34  27443.84  27343.74  27386.84         1263
# ..                  ...       ...       ...       ...       ...          ...
# 995 2023-11-14 14:00:00  36527.74  36652.74  36508.00  36649.16         1781
# 996 2023-11-14 15:00:00  36649.62  36727.34  36609.00  36677.96         2433
# 997 2023-11-14 16:00:00  36677.79  36739.54  36647.00  36704.24         1861
# 998 2023-11-14 17:00:00  36701.44  36778.64  36670.84  36763.84         3099
# 999 2023-11-14 18:00:00  36766.04  36772.14  36688.84  36704.14          374
#
#      spread  Volume  Pos  signal_long   Close_MA         std     CCI200
# 0      1942       0  NaN          NaN        NaN         NaN        NaN  \
# 1      1942       0  NaN          NaN        NaN         NaN        NaN
# 2      1942       0  NaN          NaN        NaN         NaN        NaN
# 3      1942       0  NaN          NaN        NaN         NaN        NaN
# 4      1710       0  NaN          NaN  27348.100         NaN        NaN
# ..      ...     ...  ...          ...        ...         ...        ...
# 995    1500       0 -1.0         -1.0  36492.508  238.021704  24.281267
# 996    1500       0  0.0          0.0  36556.528  239.779312  30.183238
# 997    1500       0  0.0          0.0  36606.368  240.312354  32.452734
# 998    1942       0  0.0          0.0  36664.388  240.721931  35.286443
# 999    1942       0  0.0          0.0  36699.868  241.436616  36.139980
#
#           CCI81       CCI88     CCI186      CCI29       CCI98
# 0           NaN         NaN        NaN        NaN         NaN
# 1           NaN         NaN        NaN        NaN         NaN
# 2           NaN         NaN        NaN        NaN         NaN
# 3           NaN         NaN        NaN        NaN         NaN
# 4           NaN         NaN        NaN        NaN         NaN
# ..          ...         ...        ...        ...         ...
# 995 -185.006922 -193.211278  18.004130 -85.602280 -164.202921
# 996 -145.880577 -152.958148  24.428121 -52.003717 -132.536287
# 997 -127.272335 -134.118392  26.866430 -35.004304 -118.824962
# 998 -107.173186 -114.414670  29.964196 -16.204440 -103.599025
# 999  -97.473135 -104.953883  30.916805  -7.166344  -98.863210
#
# [1000 rows x 18 columns]
